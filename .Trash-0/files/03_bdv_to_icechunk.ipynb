# %%
import xarray as xr

ds = ndvi.to_dataset(name="ndvi")
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import xarray as xr
# ----> 3 ds = ndvi.to_dataset(name="ndvi")
#       4 ds
#
# NameError: name 'ndvi' is not defined

# %%
import xarray as xr

ds = xr.open_zarr("data/ndvi.zarr")
ndvi = ds["ndvi"]
ds
